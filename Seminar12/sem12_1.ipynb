# %%
from sympy.core.symbol import symbols
from sympy.solvers.solveset import nonlinsolve
from sympy.plotting import plot as plt

a, b, c, x = symbols('a, b, c, x', real=True)
fx1 = a*31**2 + b*31 + c - 19310
fx2 = a*51**2 + b*51 + c - 52150
fx3 = a*61**2 + b*61 + c - 74570

a, b, c = tuple(*nonlinsolve([fx1, fx2, fx3], [a, b, c]))


# {(-1, -1), (-1/2, -2), (1/2, 2), (1, 1)}
# a*31**2 + b*31 + c - 19310 = f(x)
# a*51**2 + b*51 + c - 52150 = f(x)
# a*61**2 + b*61 + c - 74570 = f(x)

# %% [markdown]
# Квартиры площадью 48м2 и 54м2

# %%
fx = a*x**2 + b*x + c
p = plt(fx, (x, 0 , 70))

# %%
print(f'Стоимость 48кв.м =  {fx.subs(x, 48)}$')
print(f'Стоимость 54кв.м =  {fx.subs(x, 54)}$')
# Out:
# Стоимость 48кв.м =  46204$
# Стоимость 54кв.м =  58456$
